# %% [markdown]
# ## USST Rocketry: Boat tail manufacturing Notes
# ---
# ### Info
# Author: Nikhil Patel
# Context: This notebook serves as a logbook for USST propulsion work

# %% [markdown]
# ## June 11, 2026
#
# Today I removed the boat tail shell from the two-piece press mold. The mold was 3D printed in PETG and designed by Nishok Deenadayalan. The mold consists of a positive inner mold, which the composite material is wrapped around, and a negative outer shell, which is pressed over the layup to squeeze and evenly distribute the epoxy/resin.
#
# After allowing the composite part to cure for 48 hours, I attempted to remove it from the mold. My first approach was to heat the external face using a heat gun, with the goal of activating the mold release and making the part easier to remove.
#
# This unintentionally caused the PETG to warp. The heat gun produced enough localized heat to soften and partially melt the surface of the plastic. After noticing this, I changed the removal strategy and accepted that the mold would likely need to be sacrificed.
#
# I then used a pry bar and gentle force to separate the mold from the composite part. During this process, the PETG mold cracked in several areas due to the prying force. This likely happened because the mold release on the positive mold was not fully activated, which prevented the part from releasing cleanly.
#
# After a long removal process, the PETG mold broke into many small pieces, along with several larger shards and sections. However, the composite boat tail shell was successfully removed.
#
# The finished part had a smooth outer surface due to the press mold. The inner surface was also symmetrical and maintained the desired shape well.
#
# ### Lessons Learned
#
# For the next attempt, I would spend more time preparing the mold surface before the layup. The positive mold should be coated more evenly and thoroughly with a much larger amount of mold release. There is very little downside to using extra release agent compared to the difficulty of removing a poorly released part.
#
# I would also improve the fiberglass layup process. Instead of using shredded non-woven fiberglass placed in patches, I would prefer to use full sheets of fiberglass wrapped around the mold. The shredded fiberglass approach was used on Project UP for Launch Canada 2025, but after recovery the part split into shards and became flaky during removal. Using continuous sheets of fiberglass should help produce a stronger and more consistent composite shell.
#
# For future manufacturing, I would also consider whether a different resin or epoxy system could reduce mold damage or make demolding easier. The current resin and hardener combination may have contributed to the aggressive bonding between the composite and the PETG mold.

# %% [markdown]
# # June 15, 2026
#
# Today I picked up the second boat tail shell mold. The first mold was destroyed removing the boat tail shell and thus a new one had to be made for future construction.
#
# Since Nishok would like to be present for the future iterations, I will prep this mold for when he comes up on Saturday. As for prep, I will try to add more coats of mold release in a more symettric even manner. Last time I used my hands and willy nilly spread it on there as the honey wax mold release tended to liquify under light rubbing. This time I will let the layers cure/dry in between before I add more layers of release agent.

# %% [markdown]
# ## Friday, June 19, 2026
#
# ### Logbook Entry: Boat Tail Shell B Layup
#
# Today we worked on the second rendition of the boat tail shell. This time, the manufacturing process looked different from the first attempt. Instead of brushing epoxy resin onto the fiberglass, we used the negative mold and full 360-degree sheets of fiberglass, then poured the epoxy resin directly onto the fabric so the sheets could soak it in.
#
# Once the fiberglass was fully saturated, we added a layer of peel ply to the inside surface and pressed the positive mold face down from the top. This compressed the layup, squeezed out most of the excess resin, and helped distribute the remaining resin more evenly through the fiberglass. The peel ply also pulled resin through the fiberglass while absorbing unnecessary excess resin from the part.
#
# After the mold was assembled, we placed weights on top of the positive mold to maintain pressure during the cure. Because this process used significantly more resin than the first rendition, we chose a longer cure period of 48 hours before attempting removal.
#
# ---

# %%
from IPython.display import Image, display, HTML

img1 = Image(url='../images/2026-06-19-boat-tail-shell-b-v1-completed-1.jpg', width=400)
img2 = Image(url='../images/2026-06-19-boat-tail-shell-b-v1-completed-2.jpg', width=400)

display(HTML(f"<div style='display:flex; gap:10px; flex-wrap:wrap'>\n{img1._repr_html_()}\n{img2._repr_html_()}\n</div>"))
# Out:
# <div style='display:flex; gap:10px; flex-wrap:wrap'>
# <img src="../images/2026-06-19-boat-tail-shell-b-v1-completed-1.jpg" width="400"/>
# <img src="../images/2026-06-19-boat-tail-shell-b-v1-completed-2.jpg" width="400"/>
# </div>

# %% [markdown]
# ## Friday, June 19, 2026
#
# ### Logbook Entry: Boat Tail Shell B Mold Removal and Results
#
# Removing the mold from the second boat tail shell was difficult. Hardened epoxy had overflowed across the seam between the composite part and the 3D printed mold, which made it hard to get underneath the mold edge and begin separating the parts cleanly.
#
# During the removal process, I thought of redesigning the external mold as a three-piece mold, similar to the way regular manufacturing castings are often separated. A three-piece external mold would make it much easier to separate the mold from the finished component while still supporting our minimal-waste manufacturing method. Most importantly, it would let us reuse the mold instead of needing to 3D print a new one each time.
#
# After the mold was fully removed, it was damaged beyond reuse from being pulled off the part. The new B version of the boat tail weighs 416 grams, while the first rendition made with brushed-on epoxy weighed about 200 grams. The B version is significantly thicker and feels stronger because it does not flex nearly as much as the semi-rigid A version. This suggests that the added epoxy and the full fiberglass panel design worked as intended.
#
# The next step will be to redesign the mold so it is more effective and reusable, then paint the current boat tail for future use on Project Theseus.
#
# ---

# %%
from IPython.display import Image, display, HTML

img1 = Image(url='../images/2026-06-19-boat-tail-shell-b-v1-epoxy-overflow.jpg', width=400)
img2 = Image(url='../images/2026-06-19-boat-tail-shell-b-v1-overflowed-seam.jpg', width=400)
img3 = Image(url='../images/2026-06-19-boat-tail-shell-b-v1-post-mold-removal.jpg', width=400)
img4 = Image(url='../images/2026-06-19-boat-tail-shell-b-v1-three-piece-mold-concept.jpg', width=400)

display(HTML(f"<div style='display:flex; gap:10px; flex-wrap:wrap'>\n{img1._repr_html_()}\n{img2._repr_html_()}\n{img3._repr_html_()}\n{img4._repr_html_()}\n</div>"))
# Out:
# <div style='display:flex; gap:10px; flex-wrap:wrap'>
# <img src="../images/2026-06-19-boat-tail-shell-b-v1-epoxy-overflow.jpg" width="400"/>
# <img src="../images/2026-06-19-boat-tail-shell-b-v1-overflowed-seam.jpg" width="400"/>
# <img src="../images/2026-06-19-boat-tail-shell-b-v1-post-mold-removal.jpg" width="400"/>
# <img src="../images/2026-06-19-boat-tail-shell-b-v1-three-piece-mold-concept.jpg" width="400"/>
# </div>
